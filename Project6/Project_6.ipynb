# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# ## First Inspection: The most popular Names in 2018

# %% [markdown]
# 1. __Load__ and __inspect__ the dataset "us_baby_names.csv". __Save__ the DataFrame in __df__.

# %%
df = pd.read_csv('us_baby_names.csv')
df.head()
# Out:
#    Year       Name Gender  Count
# 0  1880       Mary      F   7065
# 1  1880       Anna      F   2604
# 2  1880       Emma      F   2003
# 3  1880  Elizabeth      F   1939
# 4  1880     Minnie      F   1746

# %% [markdown]
# 2. Find the most popular __Baby Girl Names__ in __2018__.

# %%
df_2018 = df[df['Year'] == 2018]
df_2018
# Out:
#          Year      Name Gender  Count
# 1925013  2018      Emma      F  18688
# 1925014  2018    Olivia      F  17921
# 1925015  2018       Ava      F  14924
# 1925016  2018  Isabella      F  14464
# 1925017  2018    Sophia      F  13928
# ...       ...       ...    ...    ...
# 1957041  2018     Zylas      M      5
# 1957042  2018     Zyran      M      5
# 1957043  2018     Zyrie      M      5
# 1957044  2018     Zyron      M      5
# 1957045  2018     Zzyzx      M      5
#
# [32033 rows x 4 columns]

# %%
df_girls_2018 = df.where(df['Year'] == 2018).where(df['Gender'] == 'F').sort_values(by='Count', ascending=False)
df_girls_2018
# Out:
#            Year      Name Gender    Count
# 1925013  2018.0      Emma      F  18688.0
# 1925014  2018.0    Olivia      F  17921.0
# 1925015  2018.0       Ava      F  14924.0
# 1925016  2018.0  Isabella      F  14464.0
# 1925017  2018.0    Sophia      F  13928.0
# ...         ...       ...    ...      ...
# 1957041     NaN       NaN    NaN      NaN
# 1957042     NaN       NaN    NaN      NaN
# 1957043     NaN       NaN    NaN      NaN
# 1957044     NaN       NaN    NaN      NaN
# 1957045     NaN       NaN    NaN      NaN
#
# [1957046 rows x 4 columns]

# %% [markdown]
# ( OR )

# %%
df.nunique()
df.Gender = df.Gender.astype('category')
names_2018 = df[df.Year == 2018].copy()
names_2018[names_2018.Gender == "F"].nlargest(10, "Count")
# Out:
#          Year       Name Gender  Count
# 1925013  2018       Emma      F  18688
# 1925014  2018     Olivia      F  17921
# 1925015  2018        Ava      F  14924
# 1925016  2018   Isabella      F  14464
# 1925017  2018     Sophia      F  13928
# 1925018  2018  Charlotte      F  12940
# 1925019  2018        Mia      F  12642
# 1925020  2018     Amelia      F  12301
# 1925021  2018     Harper      F  10582
# 1925022  2018     Evelyn      F  10376

# %% [markdown]
# 4. __Create__ the function __most_pop(year, gender, n)__ that returns the __n__ most popular __M/F__ Names in the __year XYZ__.

# %%
def most_pop(df, year, gender, n):
    return df.where(df['Year'] == year).where(df['Gender'] == gender).sort_values(by='Count', ascending=False).head(n)

# # ( OR )
# def most_pop(year, gender, n):
#     return df[(df.Year == year) & (df.Gender == gender)].nlargest(n, "Count")

# %% [markdown]
# ## Evergreen Names (1880 - 2018)

# %% [markdown]
# 5. Find those __Evergreen Boy Names__ that are in __1880 and 2018__ among the most popular Boy Names (__Top 20__).

# %%
most_pop(df, 1880, 'M', 20) #1880

most_pop(df, 2018,'M', 20 ) #2018
# Out:
#            Year       Name Gender    Count
# 1943042  2018.0       Liam      M  19837.0
# 1943043  2018.0       Noah      M  18267.0
# 1943044  2018.0    William      M  14516.0
# 1943045  2018.0      James      M  13525.0
# 1943046  2018.0     Oliver      M  13389.0
# 1943047  2018.0   Benjamin      M  13381.0
# 1943048  2018.0     Elijah      M  12886.0
# 1943049  2018.0      Lucas      M  12585.0
# 1943050  2018.0      Mason      M  12435.0
# 1943051  2018.0      Logan      M  12352.0
# 1943052  2018.0  Alexander      M  11989.0
# 1943053  2018.0      Ethan      M  11854.0
# 1943054  2018.0      Jacob      M  11770.0
# 1943055  2018.0    Michael      M  11620.0
# 1943056  2018.0     Daniel      M  11173.0
# 1943057  2018.0      Henry      M  10649.0
# 1943058  2018.0    Jackson      M  10323.0
# 1943059  2018.0  Sebastian      M  10054.0
# 1943060  2018.0      Aiden      M   9979.0
# 1943061  2018.0    Matthew      M   9924.0

# %% [markdown]
# 6. Find those __Evergreen Girl Names__ that are in __1880 and 2018__ among the most popular Girl Names (__Top 20__).

# %%
most_pop(df, 1880, 'F', 20)
# Out:
#       Year       Name Gender   Count
# 0   1880.0       Mary      F  7065.0
# 1   1880.0       Anna      F  2604.0
# 2   1880.0       Emma      F  2003.0
# 3   1880.0  Elizabeth      F  1939.0
# 4   1880.0     Minnie      F  1746.0
# 5   1880.0   Margaret      F  1578.0
# 6   1880.0        Ida      F  1472.0
# 7   1880.0      Alice      F  1414.0
# 8   1880.0     Bertha      F  1320.0
# 9   1880.0      Sarah      F  1288.0
# 10  1880.0      Annie      F  1258.0
# 11  1880.0      Clara      F  1226.0
# 12  1880.0       Ella      F  1156.0
# 13  1880.0   Florence      F  1063.0
# 14  1880.0       Cora      F  1045.0
# 15  1880.0     Martha      F  1040.0
# 16  1880.0      Laura      F  1012.0
# 17  1880.0     Nellie      F   995.0
# 18  1880.0      Grace      F   982.0
# 19  1880.0     Carrie      F   949.0

# %%
most_pop(df, 2018, 'F', 20)
# Out:
#            Year       Name Gender    Count
# 1925013  2018.0       Emma      F  18688.0
# 1925014  2018.0     Olivia      F  17921.0
# 1925015  2018.0        Ava      F  14924.0
# 1925016  2018.0   Isabella      F  14464.0
# 1925017  2018.0     Sophia      F  13928.0
# 1925018  2018.0  Charlotte      F  12940.0
# 1925019  2018.0        Mia      F  12642.0
# 1925020  2018.0     Amelia      F  12301.0
# 1925021  2018.0     Harper      F  10582.0
# 1925022  2018.0     Evelyn      F  10376.0
# 1925023  2018.0    Abigail      F   9796.0
# 1925024  2018.0      Emily      F   8656.0
# 1925025  2018.0  Elizabeth      F   8513.0
# 1925026  2018.0       Mila      F   8126.0
# 1925027  2018.0       Ella      F   8055.0
# 1925028  2018.0      Avery      F   8053.0
# 1925029  2018.0      Sofia      F   7621.0
# 1925030  2018.0     Camila      F   7473.0
# 1925031  2018.0       Aria      F   7394.0
# 1925032  2018.0   Scarlett      F   7182.0

# %% [markdown]
# ## Advanced Data Aggregation

# %% [markdown]
# 7. Create the following __aggregated DataFrame agg__ (you can see the first and last 5 rows):

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
agg=df.groupby(['Name','Gender']).agg(Total=('Count','sum'), No_Year=('Year', 'count'), 
                                  First_Year=('Year','min'), Last_year=('Year','max'), Max_count=('Count', 'max'))
agg
# Out:
#                 Total  No_Year  First_Year  Last_year  Max_count
# Name    Gender
# Aaban   F           0        0         NaN        NaN        NaN
#         M         114       11      2007.0     2018.0       16.0
# Aabha   F          35        5      2011.0     2016.0        9.0
#         M           0        0         NaN        NaN        NaN
# Aabid   F           0        0         NaN        NaN        NaN
# ...               ...      ...         ...        ...        ...
# Zyyanna M           0        0         NaN        NaN        NaN
# Zyyon   F           0        0         NaN        NaN        NaN
#         M           6        1      2014.0     2014.0        6.0
# Zzyzx   F           0        0         NaN        NaN        NaN
#         M          10        2      2010.0     2018.0        5.0
#
# [196800 rows x 5 columns]

# %%
def best_year(group):
  return group.nlargest(1,"Count").Year

# %%
best_y = df.groupby(['Name','Gender']).apply(best_year)  # this can take a couple of minutes!!!

# %%
# best_y
best_y.droplevel(-1)
# Out:
# Name     Gender
# Aaban    M         2014
# Aabha    F         2014
# Aabid    M         2018
# Aabidah  F         2018
# Aabir    M         2016
#                    ...
# Zyvion   M         2009
# Zyvon    M         2015
# Zyyanna  F         2010
# Zyyon    M         2014
# Zzyzx    M         2010
# Name: Year, Length: 109173, dtype: int64

# %%
agg['Best_Year'] = best_y.droplevel(-1)

# %%
agg
# Out:
#                 Total  No_Year  First_Year  Last_year  Max_count  Best_Year
# Name    Gender
# Aaban   F           0        0         NaN        NaN        NaN        NaN
#         M         114       11      2007.0     2018.0       16.0     2014.0
# Aabha   F          35        5      2011.0     2016.0        9.0     2014.0
#         M           0        0         NaN        NaN        NaN        NaN
# Aabid   F           0        0         NaN        NaN        NaN        NaN
# ...               ...      ...         ...        ...        ...        ...
# Zyyanna M           0        0         NaN        NaN        NaN        NaN
# Zyyon   F           0        0         NaN        NaN        NaN        NaN
#         M           6        1      2014.0     2014.0        6.0     2014.0
# Zzyzx   F           0        0         NaN        NaN        NaN        NaN
#         M          10        2      2010.0     2018.0        5.0     2010.0
#
# [196800 rows x 6 columns]

# %% [markdown]
# 8. __Reset__ the Index and create a RangeIndex.

# %%
agg.reset_index(inplace=True)

# %%
agg
# Out:
#            Name Gender  Total  No_Year  First_Year  Last_year  Max_count  \
# 0         Aaban      F      0        0         NaN        NaN        NaN
# 1         Aaban      M    114       11      2007.0     2018.0       16.0
# 2         Aabha      F     35        5      2011.0     2016.0        9.0
# 3         Aabha      M      0        0         NaN        NaN        NaN
# 4         Aabid      F      0        0         NaN        NaN        NaN
# ...         ...    ...    ...      ...         ...        ...        ...
# 196795  Zyyanna      M      0        0         NaN        NaN        NaN
# 196796    Zyyon      F      0        0         NaN        NaN        NaN
# 196797    Zyyon      M      6        1      2014.0     2014.0        6.0
# 196798    Zzyzx      F      0        0         NaN        NaN        NaN
# 196799    Zzyzx      M     10        2      2010.0     2018.0        5.0
#
#         Best_Year
# 0             NaN
# 1          2014.0
# 2          2014.0
# 3             NaN
# 4             NaN
# ...           ...
# 196795        NaN
# 196796        NaN
# 196797     2014.0
# 196798        NaN
# 196799     2010.0
#
# [196800 rows x 8 columns]

# %% [markdown]
# 9. __Filter__ agg for the combination (Mary, F)

# %%
agg[(agg.Name == 'Mary') & (agg.Gender == 'F')]
# Out:
#         Name Gender    Total  No_Year  First_Year  Last_year  Max_count  \
# 123434  Mary      F  4125675      139      1880.0     2018.0    73985.0
#
#         Best_Year
# 123434     1921.0

# %% [markdown]
# ## Most Popular Names of all Times

# %% [markdown]
# 10. __Find__ the __10 most popular__ Male and Female Names of all Times (most popular in terms of total count). See Screenshot with final result below.

# %%
# df.where(df.Gender == 'F').groupby(['Name', 'Gender']).agg(Most_popular_count=('Count', 'sum')).nlargest(20, 'Most_popular_count')
# df.where(df.Gender == 'M').groupby(['Name', 'Gender']).agg(Most_popular_count=('Count', 'sum')).nlargest(20, 'Most_popular_count')
# ( OR )
agg.groupby('Gender').apply(lambda x: x.nlargest(10, 'Total'))
# Out:
#                     Name Gender    Total  No_Year  First_Year  Last_year  \
# Gender
# F      123434       Mary      F  4125675      139      1880.0     2018.0
#        55100   Elizabeth      F  1638349      139      1880.0     2018.0
#        142434   Patricia      F  1572016      135      1884.0     2018.0
#        83680    Jennifer      F  1467207      101      1916.0     2018.0
#        113152      Linda      F  1452668      139      1880.0     2018.0
#        21348     Barbara      F  1434397      139      1880.0     2018.0
#        121050   Margaret      F  1248985      139      1880.0     2018.0
#        170120      Susan      F  1121703      139      1880.0     2018.0
#        51256     Dorothy      F  1107635      139      1880.0     2018.0
#        157344      Sarah      F  1077746      139      1880.0     2018.0
# M      78267       James      M  5164280      139      1880.0     2018.0
#        86969        John      M  5124817      139      1880.0     2018.0
#        151747     Robert      M  4820129      139      1880.0     2018.0
#        127667    Michael      M  4362731      139      1880.0     2018.0
#        188363    William      M  4117369      139      1880.0     2018.0
#        43431       David      M  3621322      139      1880.0     2018.0
#        88407      Joseph      M  2613304      139      1880.0     2018.0
#        150755    Richard      M  2565301      139      1880.0     2018.0
#        32931     Charles      M  2392779      139      1880.0     2018.0
#        177369     Thomas      M  2311849      139      1880.0     2018.0
#
#                Max_count  Best_Year
# Gender
# F      123434    73985.0     1921.0
#        55100     20744.0     1990.0
#        142434    56442.0     1951.0
#        83680     63603.0     1972.0
#        113152    99689.0     1947.0
#        21348     48792.0     1947.0
#        121050    28467.0     1921.0
#        170120    47402.0     1955.0
#        51256     39999.0     1924.0
#        157344    28484.0     1982.0
# M      78267     94757.0     1947.0
#        86969     88319.0     1947.0
#        151747    91640.0     1947.0
#        127667    92704.0     1957.0
#        188363    66989.0     1947.0
#        43431     86253.0     1955.0
#        88407     32732.0     1956.0
#        150755    58868.0     1946.0
#        32931     40770.0     1947.0
#        177369    48652.0     1952.0

# %% [markdown]
# ## General Trends over time (1880 - 2018)

# %% [markdown]
# 11. __Count__ the total number of __registered Babies per Year__ and visualize. __Create__ the Plot:

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
babies_per_year = df.groupby('Year').Count.sum()
babies_per_year
# Out:
# Year
# 1880     201484
# 1881     192696
# 1882     221533
# 1883     216944
# 1884     243461
#          ...
# 2014    3698914
# 2015    3691990
# 2016    3657797
# 2017    3561975
# 2018    3487353
# Name: Count, Length: 139, dtype: int64

# %%
babies_per_year.plot(kind='bar', y='Count', figsize=(15,10), fontsize =15)
plt.xticks(ticks=(range(0, len(babies_per_year),5)))
plt.title('Registered Babies per Year', fontsize=20)
plt.show()

# %% [markdown]
# 12. __Count__ the total number of __Unique Names per Year__ and visualize. __Create__ the Plot:

# %%
unique_names = df.groupby('Year').Name.count()
unique_names
# Out:
# Year
# 1880     2000
# 1881     1935
# 1882     2127
# 1883     2084
# 1884     2297
#         ...
# 2014    33243
# 2015    33121
# 2016    33010
# 2017    32590
# 2018    32033
# Name: Name, Length: 139, dtype: int64

# %%
unique_names.plot(kind='bar', y='Count', figsize=(15,10), fontsize =15)
plt.xticks(ticks=(range(0, len(babies_per_year),5)))
plt.title('Unique names per Year', fontsize=20)
plt.show()

# %% [markdown]
# ## Creating the Features "Popularity" and "Rank"

# %% [markdown]
# 13. __Add__ the column __"Popularity"__ to df: <br>
#
# - Popularity in __babies per million__ (example: assume 2,000,000 registered Girl Names in 1950, thereof 100,000 Maries -> Popularity Score in 1950 for (Mary, F) is 100,000 / 2,000,000 * 1,000,000 = 50,000 per million.)

# %%
df.head()
# Out:
#    Year       Name Gender  Count
# 0  1880       Mary      F   7065
# 1  1880       Anna      F   2604
# 2  1880       Emma      F   2003
# 3  1880  Elizabeth      F   1939
# 4  1880     Minnie      F   1746

# %%
# __Popularity (babies per million)__

print(df.groupby(['Year','Gender']).Count.sum())
print("@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@")
print(df.groupby(["Year", "Gender"]).Count.transform("sum"))


df['Popularity'] = df.Count.div(df.groupby(['Year', 'Gender']).Count.transform('sum'))*1000000

df
# Out:
# Year  Gender
# 1880  F           90994
#       M          110490
# 1881  F           91953
#       M          100743
# 1882  F          107847
#                  ...
# 2016  M         1891585
# 2017  F         1719138
#       M         1842837
# 2018  F         1686961
#       M         1800392
# Name: Count, Length: 278, dtype: int64
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# 0            90994
# 1            90994
# 2            90994
# 3            90994
# 4            90994
#             ...
# 1957041    1800392
# 1957042    1800392
# 1957043    1800392
# 1957044    1800392
# 1957045    1800392
# Name: Count, Length: 1957046, dtype: int64
#          Year       Name Gender  Count    Popularity
# 0        1880       Mary      F   7065  77642.481922
# 1        1880       Anna      F   2604  28617.271468
# 2        1880       Emma      F   2003  22012.440381
# 3        1880  Elizabeth      F   1939  21309.097303
# 4        1880     Minnie      F   1746  19188.078335
# ...       ...        ...    ...    ...           ...
# 1957041  2018      Zylas      M      5      2.777173
# 1957042  2018      Zyran      M      5      2.777173
# 1957043  2018      Zyrie      M      5      2.777173
# 1957044  2018      Zyron      M      5      2.777173
# 1957045  2018      Zzyzx      M      5      2.777173
#
# [1957046 rows x 5 columns]

# %% [markdown]
# 14. __Add__ the column __"Rank"__ to df: <br>
#
# - Rank (example: assume Mary is the most popular Girl Name in 1950 -> Rank 1 for (Mary, F) in 1950.

# %%
rank=df.groupby(['Year','Gender']).Count.apply(lambda x: x.rank(ascending=False))
df['Rank'] = rank
df
# Out:
# <ipython-input-137-4df70d81fd94>:1: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   rank=df.groupby(['Year','Gender']).Count.apply(lambda x: x.rank(ascending=False))
#          Year       Name Gender  Count    Popularity     Rank
# 0        1880       Mary      F   7065  77642.481922      1.0
# 1        1880       Anna      F   2604  28617.271468      2.0
# 2        1880       Emma      F   2003  22012.440381      3.0
# 3        1880  Elizabeth      F   1939  21309.097303      4.0
# 4        1880     Minnie      F   1746  19188.078335      5.0
# ...       ...        ...    ...    ...           ...      ...
# 1957041  2018      Zylas      M      5      2.777173  13042.0
# 1957042  2018      Zyran      M      5      2.777173  13042.0
# 1957043  2018      Zyrie      M      5      2.777173  13042.0
# 1957044  2018      Zyron      M      5      2.777173  13042.0
# 1957045  2018      Zzyzx      M      5      2.777173  13042.0
#
# [1957046 rows x 6 columns]

# %% [markdown]
# ## Visualizing Name Trends over Time

# %% [markdown]
# 15. __Visualize__ Popularity and Rank over time (see example below).

# %%
mary = df[(df.Name == "Mary") & (df.Gender == "F")]
mary.head()
# Out:
#       Year  Name Gender  Count    Popularity  Rank
# 0     1880  Mary      F   7065  77642.481922   1.0
# 2000  1881  Mary      F   6919  75244.962100   1.0
# 3935  1882  Mary      F   8148  75551.475702   1.0
# 6062  1883  Mary      F   8012  71332.543915   1.0
# 8146  1884  Mary      F   9217  71439.090367   1.0

# %%
fig, ax1 = plt.subplots(figsize =(12, 8))
ax1.bar(mary.Year, height=mary.Popularity, label='Popularity' )
ax2=ax1.twinx()
ax2.plot(mary.Year, mary.Rank, label='Rank', color='red')
ax1.set_xlabel('Year', fontsize=15)
ax1.set_ylabel('Babies per million', fontsize=15)
ax2.set_ylabel('Rank', fontsize=15)
ax1.set_title('Mary', fontsize=18)
ax1.legend(loc = 2, fontsize = 15)
ax2.legend(loc = 1, fontsize = 15)
plt.show()

# %%
def plot_name(name,gender, crit='Popularity'):
  data=df.loc[(df.Name == name) & (df.Gender == gender), ['Name','Gender','Year','Rank',crit]]
  data = data.set_index('Year')

  fig, ax1 = plt.subplots(figsize= (12,8))
  ax1.bar(x=data.index, height=data[crit], label=crit)
  ax2 = ax1.twinx()
  ax2.plot(data.index, data.Rank, color = "red", label = "Rank")
  ax1.set_xlabel("Year", fontsize = 15)
  ax1.set_ylabel(crit, fontsize = 15)
  ax2.set_ylabel("Rank", fontsize = 15)
  ax1.set_title(name, fontsize = 18)
  ax1.legend(loc = 2, fontsize = 15)
  ax2.legend(loc = 1, fontsize = 15)
  plt.show()

# %%
plot_name("Mary", "F")

# %%
plot_name("Mary", "F", crit = "Count")

# %% [markdown]
# # Why does a Name´s Popularity suddenly change? (Part 1)

# %% [markdown]
# 17. __Add__ the additional columns __"Pop_lag1"__ (Popularity one year ago) and __"Pop_diff"__ (change in popularity from previous year to this year) to df.

# %%
df
# Out:
#          Year       Name Gender  Count    Popularity     Rank
# 0        1880       Mary      F   7065  77642.481922      1.0
# 1        1880       Anna      F   2604  28617.271468      2.0
# 2        1880       Emma      F   2003  22012.440381      3.0
# 3        1880  Elizabeth      F   1939  21309.097303      4.0
# 4        1880     Minnie      F   1746  19188.078335      5.0
# ...       ...        ...    ...    ...           ...      ...
# 1957041  2018      Zylas      M      5      2.777173  13042.0
# 1957042  2018      Zyran      M      5      2.777173  13042.0
# 1957043  2018      Zyrie      M      5      2.777173  13042.0
# 1957044  2018      Zyron      M      5      2.777173  13042.0
# 1957045  2018      Zzyzx      M      5      2.777173  13042.0
#
# [1957046 rows x 6 columns]

# %%
df["Pop_lag1"] = df.groupby(["Name", "Gender"]).Popularity.shift()
df
# Out:
#          Year       Name Gender  Count    Popularity     Rank  Pop_lag1
# 0        1880       Mary      F   7065  77642.481922      1.0       NaN
# 1        1880       Anna      F   2604  28617.271468      2.0       NaN
# 2        1880       Emma      F   2003  22012.440381      3.0       NaN
# 3        1880  Elizabeth      F   1939  21309.097303      4.0       NaN
# 4        1880     Minnie      F   1746  19188.078335      5.0       NaN
# ...       ...        ...    ...    ...           ...      ...       ...
# 1957041  2018      Zylas      M      5      2.777173  13042.0  3.798491
# 1957042  2018      Zyran      M      5      2.777173  13042.0  3.138835
# 1957043  2018      Zyrie      M      5      2.777173  13042.0  2.713208
# 1957044  2018      Zyron      M      5      2.777173  13042.0  8.139624
# 1957045  2018      Zzyzx      M      5      2.777173  13042.0  2.608955
#
# [1957046 rows x 7 columns]

# %%
df[df.Name == 'Mary']
# Out:
#          Year  Name Gender  Count    Popularity     Rank      Pop_lag1
# 0        1880  Mary      F   7065  77642.481922      1.0           NaN
# 1273     1880  Mary      M     27    244.366006    329.0           NaN
# 2000     1881  Mary      F   6919  75244.962100      1.0  77642.481922
# 3238     1881  Mary      M     29    287.861191    301.0    244.366006
# 3935     1882  Mary      F   8148  75551.475702      1.0  75244.962100
# ...       ...   ...    ...    ...           ...      ...           ...
# 1825554  2014  Mary      M      5      2.608835  13069.0      3.167940
# 1826414  2015  Mary      F   2631   1477.713818    123.0   1476.702107
# 1859539  2016  Mary      F   2508   1419.988088    127.0   1477.713818
# 1892548  2017  Mary      F   2402   1397.211859    126.0   1419.988088
# 1925138  2018  Mary      F   2327   1379.403555    126.0   1397.211859
#
# [270 rows x 7 columns]

# %%
df['Pop_diff'] = df['Popularity'] - df['Pop_lag1']
df
# Out:
#          Year       Name Gender  Count    Popularity     Rank  Pop_lag1  \
# 0        1880       Mary      F   7065  77642.481922      1.0       NaN
# 1        1880       Anna      F   2604  28617.271468      2.0       NaN
# 2        1880       Emma      F   2003  22012.440381      3.0       NaN
# 3        1880  Elizabeth      F   1939  21309.097303      4.0       NaN
# 4        1880     Minnie      F   1746  19188.078335      5.0       NaN
# ...       ...        ...    ...    ...           ...      ...       ...
# 1957041  2018      Zylas      M      5      2.777173  13042.0  3.798491
# 1957042  2018      Zyran      M      5      2.777173  13042.0  3.138835
# 1957043  2018      Zyrie      M      5      2.777173  13042.0  2.713208
# 1957044  2018      Zyron      M      5      2.777173  13042.0  8.139624
# 1957045  2018      Zzyzx      M      5      2.777173  13042.0  2.608955
#
#          Pop_diff
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 1957041 -1.021318
# 1957042 -0.361662
# 1957043  0.063965
# 1957044 -5.362451
# 1957045  0.168218
#
# [1957046 rows x 8 columns]

# %%
df[(df.Name == "Mary") & (df.Gender == "F")]
# Out:
#          Year  Name Gender  Count    Popularity   Rank      Pop_lag1  \
# 0        1880  Mary      F   7065  77642.481922    1.0           NaN
# 2000     1881  Mary      F   6919  75244.962100    1.0  77642.481922
# 3935     1882  Mary      F   8148  75551.475702    1.0  75244.962100
# 6062     1883  Mary      F   8012  71332.543915    1.0  75551.475702
# 8146     1884  Mary      F   9217  71439.090367    1.0  71332.543915
# ...       ...   ...    ...    ...           ...    ...           ...
# 1793168  2014  Mary      F   2632   1476.702107  120.0   1513.715369
# 1826414  2015  Mary      F   2631   1477.713818  123.0   1476.702107
# 1859539  2016  Mary      F   2508   1419.988088  127.0   1477.713818
# 1892548  2017  Mary      F   2402   1397.211859  126.0   1419.988088
# 1925138  2018  Mary      F   2327   1379.403555  126.0   1397.211859
#
#             Pop_diff
# 0                NaN
# 2000    -2397.519822
# 3935      306.513601
# 6062    -4218.931787
# 8146      106.546451
# ...              ...
# 1793168   -37.013262
# 1826414     1.011711
# 1859539   -57.725730
# 1892548   -22.776229
# 1925138   -17.808304
#
# [139 rows x 8 columns]

# %%
df.nlargest(20,'Pop_diff')
# Out:
#         Year      Name Gender  Count    Popularity  Rank      Pop_lag1  \
# 431066  1947     Linda      F  99689  56236.224976   1.0  33546.795584
# 321479  1935   Shirley      F  42358  40398.317993   2.0  21874.356531
# 922468  1983    Ashley      F  33293  19930.187772   4.0   8774.639361
# 711426  1971  Jennifer      F  56783  34133.547814   1.0  26403.416193
# 47952   1898     Dewey      M   1115   9088.019301  19.0   1401.243382
# 726721  1972  Jennifer      F  63603  41813.296659   1.0  34133.547814
# 312301  1934   Shirley      F  22840  21874.356531   4.0  14203.488412
# 645417  1966  Michelle      F  27151  16047.477506   4.0   9186.178467
# 751941  1973     Jason      M  46683  29939.989187   3.0  23080.621302
# 844807  1979    Amanda      F  31928  19889.848316   3.0  13393.836368
# 696647  1970  Jennifer      F  46157  26403.416193   1.0  19977.960342
# 472253  1951   Deborah      F  42052  23351.039669   4.0  16965.497515
# 366312  1940     Linda      F  18369  16065.061356   8.0   9770.252254
# 838069  1978  Nicholas      M  16353   9955.734029  25.0   3699.334898
# 472267  1951     Debra      F  17066   9476.572886  18.0   3607.568890
# 9337    1884    Grover      M    802   7007.916674  20.0   1213.859020
# 461953  1950   Deborah      F  29063  16965.497515   7.0  11227.739162
# 791025  1976     Jamie      F  12538   8557.602397  18.0   2904.426266
# 608783  1963      Lisa      F  56040  29076.856503   1.0  23430.845749
# 633462  1965      Lisa      F  60269  34145.910326   1.0  28644.577137
#
#             Pop_diff
# 431066  22689.429392
# 321479  18523.961462
# 922468  11155.548411
# 711426   7730.131621
# 47952    7686.775919
# 726721   7679.748845
# 312301   7670.868118
# 645417   6861.299039
# 751941   6859.367885
# 844807   6496.011948
# 696647   6425.455851
# 472253   6385.542154
# 366312   6294.809102
# 838069   6256.399131
# 472267   5869.003996
# 9337     5794.057654
# 461953   5737.758353
# 791025   5653.176131
# 608783   5646.010754
# 633462   5501.333189

# %%
df.nsmallest(20, 'Pop_diff')
# Out:
#          Year      Name Gender  Count    Popularity  Rank      Pop_lag1  \
# 339412   1937   Shirley      F  26816  25204.262994   4.0  33797.507168
# 330516   1936   Shirley      F  35161  33797.507168   2.0  40398.317993
# 461947   1950     Linda      F  80431  46951.516726   1.0  53199.224714
# 472250   1951     Linda      F  73978  41079.216509   1.0  46951.516726
# 961380   1985  Jennifer      F  42651  24789.454412   3.0  30032.147389
# 482712   1952     Linda      F  67082  36174.484375   1.0  41079.216509
# 696648   1970      Lisa      F  38963  22288.196917   2.0  26692.409241
# 51103    1899     Dewey      M    499   4698.239337  39.0   9088.019301
# 437173   1947   Richard      M  58521  31989.596453   5.0  36252.451758
# 537623   1957   Deborah      F  40071  19601.225058   6.0  23826.731344
# 6062     1883      Mary      F   8012  71332.543915   1.0  75551.475702
# 9322     1884   Charles      M   4802  41960.119537   5.0  46126.642772
# 504196   1954     Linda      F  55381  28520.371510   2.0  32572.095261
# 808401   1977       Amy      F  26732  17436.407208   3.0  21391.275859
# 96450    1911    Willie      M   2492  11028.012568  14.0  14916.688979
# 549189   1958   Cynthia      F  31003  15416.991760   8.0  19236.799098
# 1094386  1991  Brittany      F  29089  15516.483563   3.0  19248.894309
# 981466   1986  Jennifer      F  36185  21096.308423   4.0  24789.454412
# 57940    1901     James      M   4735  44473.039101   3.0  48145.933014
# 348359   1938   Shirley      F  23767  21540.352248   5.0  25204.262994
#
#             Pop_diff
# 339412  -8593.244174
# 330516  -6600.810824
# 461947  -6247.707988
# 472250  -5872.300217
# 961380  -5242.692976
# 482712  -4904.732133
# 696648  -4404.212323
# 51103   -4389.779964
# 437173  -4262.855305
# 537623  -4225.506286
# 6062    -4218.931787
# 9322    -4166.523235
# 504196  -4051.723751
# 808401  -3954.868652
# 96450   -3888.676411
# 549189  -3819.807338
# 1094386 -3732.410746
# 981466  -3693.145989
# 57940   -3672.893914
# 348359  -3663.910747

# %% [markdown]
#  __Create__ the popularity/rank plot:

# %% [markdown]
# __Search__ the Web for the Names __"Linda"__, __"Shirley"__ and __"Jason"__ and __find out__ why the popularity suddenly changed/spiked.

# %%
plot_name("Linda", "F")

# %%
plot_name('Shirley', 'F')

# %%
plot_name('Jason','F')

# %% [markdown]
# ## Most Popular Unisex Names

# %% [markdown]
#  __Find__ the most popular __Unisex Names__ of all times. (Unisex names are names given to Boys and Girls).  bold text

# %%
unisex = df.groupby(["Name", "Gender"]).Count.sum().unstack()
unisex.replace(0, np.nan, inplace=True)
unisex.dropna(inplace=True)
unisex['Total']=unisex['F'] + unisex['M']
unisex.nlargest(20, 'Total')
# Out:
# Gender               F          M      Total
# Name
# James          23399.0  5164280.0  5187679.0
# John           21691.0  5124817.0  5146508.0
# Robert         20099.0  4820129.0  4840228.0
# Michael        21732.0  4362731.0  4384463.0
# Mary         4125675.0    15165.0  4140840.0
# William        15958.0  4117369.0  4133327.0
# David          12907.0  3621322.0  3634229.0
# Joseph         10654.0  2613304.0  2623958.0
# Richard         9531.0  2565301.0  2574832.0
# Charles        12418.0  2392779.0  2405197.0
# Thomas          8472.0  2311849.0  2320321.0
# Christopher     9470.0  2029565.0  2039035.0
# Daniel          8181.0  1918752.0  1926933.0
# Elizabeth    1638349.0     5181.0  1643530.0
# Matthew         5519.0  1600511.0  1606030.0
# Patricia     1572016.0     4962.0  1576978.0
# George          9930.0  1467292.0  1477222.0
# Jennifer     1467207.0     4837.0  1472044.0
# Linda        1452668.0     3757.0  1456425.0
# Anthony         7069.0  1440846.0  1447915.0
